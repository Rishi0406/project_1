# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt

base_url="https://api.rawg.io/api/"

# %%
platform_id=[]
platform_name=[]
platform_gamecount=[]

platforms=requests.get(base_url+"platforms/lists/parents").json()
for i in range(len(platforms["results"])):
    platform_id.append(platforms["results"][i]["id"])
    platform_name.append(platforms["results"][i]["name"])
    game_count=0
    for j in range(len(platforms["results"][i]["platforms"])):
        game_count=game_count+platforms["results"][i]["platforms"][j]["games_count"]
    platform_gamecount.append(game_count)
    
platform_df = pd.DataFrame(
    {
        "ID" : platform_id,
        "name" : platform_name,
        "number of games" : platform_gamecount
    }
)
platform_df=platform_df.sort_values("number of games",ascending=False)
platform_df
# Out:
#     ID               name  number of games
# 0    1                 PC           234079
# 13  14                Web            88574
# 3    4                iOS            66313
# 5    5    Apple Macintosh            54825
# 6    6              Linux            36499
# 4    8            Android            30130
# 7    7           Nintendo            15439
# 1    2        PlayStation            15290
# 2    3               Xbox             6668
# 9   10  Commodore / Amiga             2025
# 10  11               SEGA             1981
# 8    9              Atari             1635
# 12  13            Neo Geo               97
# 11  12                3DO               88

# %%
fig,ax = plt.subplots()
ax.hlines(platform_df["name"], xmin=0, xmax=platform_df["number of games"])
ax.plot(platform_df["number of games"], platform_df["name"], "o", color='black')
ax.set(title="Most Popular Gaming Platforms")
# Out:
# [Text(0.5, 1.0, 'Most Popular Gaming Platforms')]

# %%
store_id=[]
store_name=[]
store_gamecount=[]

stores=requests.get(base_url+"stores").json()
for i in range(len(stores["results"])):
    store_id.append(stores["results"][i]["id"])
    store_name.append(stores["results"][i]["name"])
    store_gamecount.append(stores["results"][i]["games_count"])
    
store_df = pd.DataFrame(
    {
        "ID" : store_id,
        "name" : store_name,
        "number of games" : store_gamecount
    }
)
store_df
# Out:
#    ID               name  number of games
# 0   1              Steam            41716
# 1   3  PlayStation Store             6473
# 2   2         Xbox Store             3019
# 3   4          App Store            64787
# 4   5                GOG             2693
# 5   6     Nintendo Store             7733
# 6   7     Xbox 360 Store             1760
# 7   8        Google Play            16064
# 8   9            itch.io           259224
# 9  11         Epic Games              258

# %%
game_name=[]
game_playtime=[]
game_platform_num=[]
game_platform=[]
game_store_num=[]
game_store=[]
game_genre=[]
game_releasedate=[]
game_rating=[]
game_rating_top=[]
game_rating_count=[]
game_metacritic=[]
added_count=[]

count=1
while count:
    response=requests.get(base_url+"games?dates=2019-01-01,2019-12-31&page="+str(count))
    if response.status_code!=200:
        break
    else:
        games=response.json()
        print(base_url+"games?dates=2019-01-01,2019-12-31&page="+str(count))
        for i in range(len(games["results"])):
            game_name.append(games["results"][i]["name"])
            game_playtime.append(games["results"][i]["playtime"])
            try:
                game_platform_num.append(len(games["results"][i]["platforms"]))
                game_platform_temp=[]
                for j in range(len(games["results"][i]["parent_platforms"])):
                    game_platform_temp.append(games["results"][i]["parent_platforms"][j]["platform"]["name"])
                game_platform.append(game_platform_temp)
            except:
                game_platform_num.append("None")
#
#                                               platforms number of stores  \
# 0                                     [PC, PlayStation]                3
# 1                               [PC, PlayStation, Xbox]                3
# 2     [PC, PlayStation, Xbox, Apple Macintosh, Ninte...                3
# 3                               [PC, PlayStation, Xbox]                1
# 4                               [PC, PlayStation, Xbox]                2
# ...                                                 ...              ...
# 9995                                               [PC]                1
# 9996                                              [Web]                1
# 9997                                              [Web]                1
# 9998                                               [PC]                1
# 9999                                              [Web]                1
#
#                                       stores  \
# 0     [Steam, PlayStation Store, Epic Games]
# 1     [Steam, PlayStation Store, Xbox Store]
# 2     [Steam, PlayStation Store, Xbox Store]
# 3                                    [Steam]
# 4                        [Steam, Xbox Store]
# ...                                      ...
# 9995                               [itch.io]
# 9996                               [itch.io]
# 9997                               [itch.io]
# 9998                               [itch.io]
# 9999                               [itch.io]
#
#                                         genres release date  rating  \
# 0                          [Adventure, Action]   2019-11-08    4.37
# 1                                [Action, RPG]   2019-03-22    4.38
# 2     [Shooter, Massively Multiplayer, Action]   2019-02-04    3.68
# 3                       [Shooter, Action, RPG]   2019-04-03    3.82
# 4                                     [Action]   2019-03-08    4.24
# ...                                        ...          ...     ...
# 9995                                 [Shooter]   2019-06-06    0.00
# 9996                                  [Puzzle]   2019-06-06    0.00
# 9997                                        []   2019-06-06    0.00
# 9998                                     [RPG]   2019-06-06    0.00
# 9999                              [Platformer]   2019-06-06    0.00
#
#       max rating  rating count  metacritic score  \
# 0              5           718              82.0
# 1              5           995              90.0
# 2              4          1219              88.0
# 3              4           592              78.0
# 4              5           806              88.0
# ...          ...           ...               ...
# 9995           0             0               NaN
# 9996           0             0               NaN
# 9997           0             0               NaN
# 9998           0             0               NaN
# 9999           0             0               NaN
#
#                                                   added
# 0     {'yet': 232, 'owned': 1889, 'beaten': 424, 'to...
# 1     {'yet': 213, 'owned': 1692, 'beaten': 512, 'to...
# 2     {'yet': 58, 'owned': 2307, 'beaten': 163, 'top...
# 3     {'yet': 189, 'owned': 2458, 'beaten': 341, 'to...
# 4     {'yet': 179, 'owned': 1571, 'beaten': 564, 'to...
# ...                                                 ...
# 9995                                               None
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999                                               None
#
# [10000 rows x 13 columns]

# %%
game_df.to_csv("game.csv")

# %%
game_df_rated=game_df[game_df["rating"]>0.00]
game_df_metacritic=game_df_rated.dropna(how="any",subset=["metacritic score"])
game_df_metacritic
# Out:
#                                        name  playtime number of platforms  \
# 0                           Death Stranding         0                   2
# 1                 Sekiro: Shadows Die Twice        17                   3
# 2                              Apex Legends         0                   5
# 3     Borderlands Game of the Year Enhanced         2                   3
# 4                           Devil May Cry 5        10                   3
# ..                                      ...       ...                 ...
# 467                             The Touryst         0                   1
# 484  Oceanhorn 2: Knights of the Lost Realm         0                   4
# 598             Harry Potter: Wizards Unite         0                   2
# 742                         Dr. Mario World         0                   2
# 769                              Gears POP!         0                   3
#
#                                              platforms number of stores  \
# 0                                    [PC, PlayStation]                3
# 1                              [PC, PlayStation, Xbox]                3
# 2    [PC, PlayStation, Xbox, Apple Macintosh, Ninte...                3
# 3                              [PC, PlayStation, Xbox]                1
# 4                              [PC, PlayStation, Xbox]                2
# ..                                                 ...              ...
# 467                                         [Nintendo]                1
# 484            [PC, PlayStation, iOS, Apple Macintosh]                1
# 598                                     [iOS, Android]                2
# 742                                     [iOS, Android]                2
# 769                                 [PC, iOS, Android]                2
#
#                                      stores  \
# 0    [Steam, PlayStation Store, Epic Games]
# 1    [Steam, PlayStation Store, Xbox Store]
# 2    [Steam, PlayStation Store, Xbox Store]
# 3                                   [Steam]
# 4                       [Steam, Xbox Store]
# ..                                      ...
# 467                        [Nintendo Store]
# 484                             [App Store]
# 598                [App Store, Google Play]
# 742                [App Store, Google Play]
# 769                [App Store, Google Play]
#
#                                        genres release date  rating  \
# 0                         [Adventure, Action]   2019-11-08    4.37
# 1                               [Action, RPG]   2019-03-22    4.38
# 2    [Shooter, Massively Multiplayer, Action]   2019-02-04    3.68
# 3                      [Shooter, Action, RPG]   2019-04-03    3.82
# 4                                    [Action]   2019-03-08    4.24
# ..                                        ...          ...     ...
# 467                       [Adventure, Action]   2019-11-14    3.27
# 484                       [Adventure, Action]   2019-09-19    3.64
# 598                          [Adventure, RPG]   2019-06-21    2.46
# 742                          [Casual, Puzzle]   2019-07-10    3.55
# 769                        [Strategy, Action]   2019-08-22    2.88
#
#      max rating  rating count  metacritic score  \
# 0             5           718              82.0
# 1             5           995              90.0
# 2             4          1219              88.0
# 3             4           592              78.0
# 4             5           806              88.0
# ..          ...           ...               ...
# 467           4            11              79.0
# 484           4            11              73.0
# 598           3            13              64.0
# 742           4            11              58.0
# 769           4             8              64.0
#
#                                                  added
# 0    {'yet': 232, 'owned': 1889, 'beaten': 424, 'to...
# 1    {'yet': 213, 'owned': 1692, 'beaten': 512, 'to...
# 2    {'yet': 58, 'owned': 2307, 'beaten': 163, 'top...
# 3    {'yet': 189, 'owned': 2458, 'beaten': 341, 'to...
# 4    {'yet': 179, 'owned': 1571, 'beaten': 564, 'to...
# ..                                                 ...
# 467  {'yet': 2, 'owned': 5, 'beaten': 4, 'toplay': ...
# 484  {'yet': 4, 'owned': 4, 'beaten': 3, 'toplay': ...
# 598  {'yet': 2, 'owned': 5, 'beaten': 1, 'toplay': ...
# 742  {'yet': 1, 'owned': 3, 'beaten': 1, 'toplay': ...
# 769  {'yet': 1, 'owned': 3, 'beaten': 1, 'toplay': ...
#
# [161 rows x 13 columns]

# %%
print(json.dumps(games["results"][19],indent=2))
# Out:
# {
#   "slug": "leemon-the-darkest-timeline",
#   "name": "LEEMON: The Darkest Timeline",
#   "playtime": 0,
#   "platforms": [
#     {
#       "platform": {
#         "id": 171,
#         "name": "Web",
#         "slug": "web"
#       }
#     }
#   ],
#   "stores": [
#     {
#       "store": {
#         "id": 9,
#         "name": "itch.io",
#         "slug": "itch"
#       }
#     }
#   ],
#   "released": "2019-06-06",
#   "tba": false,
#   "background_image": "https://media.rawg.io/media/screenshots/e86/e862d6377c720581d606b4254cb279d1.jpg",
#   "rating": 0.0,
#   "rating_top": 0,
#   "ratings": [],
#   "ratings_count": 0,
#   "reviews_text_count": 0,
#   "added": 0,
#   "added_by_status": null,
#   "metacritic": null,
#   "suggestions_count": 22,
#   "id": 325475,
#   "score": null,
#   "clip": null,
#   "tags": [
#     {
#       "id": 1017,
#       "name": "browser",
#       "slug": "browser",
#       "language": "eng",
#       "games_count": 535,
#       "image_background": "https://media.rawg.io/media/screenshots/4bc/4bcf552f992f3a1ea286810c1775b05c.jpg"
#     }
#   ],
#   "user_game": null,
#   "reviews_count": 0,
#   "community_rating": 0,
#   "saturated_color": "0f0f0f",
#   "dominant_color": "0f0f0f",
#   "short_screenshots": [
#     {
#       "id": -1,
#       "image": "https://media.rawg.io/media/screenshots/e86/e862d6377c720581d606b4254cb279d1.jpg"
#     },
#     {
#       "id": 1955699,
#       "image": "https://media.rawg.io/media/screenshots/e86/e862d6377c720581d606b4254cb279d1.jpg"
#     }
#   ],
#   "parent_platforms": [
#     {
#       "platform": {
#         "id": 14,
#         "name": "Web",
#         "slug": "web"
#       }
#     }
#   ],
#   "genres": [
#     {
#       "id": 83,
#       "name": "Platformer",
#       "slug": "platformer"
#     }
#   ]
# }

# %%
platform_df["rating"]=0
platform_df["rating count"]=0

for i in game_df_rated.index:
    rating=game_df_rated.loc[i,"rating"]*game_df_rated.loc[i,"rating count"]
    rating_count=game_df_rated.loc[i,"rating count"]
    platform=game_df_rated.loc[i,"platforms"]
    for j in platform:
        for k in platform_df.index:
            if platform_df.loc[k,"name"]==j:
                platform_df.loc[k,"rating"]=platform_df.loc[k,"rating"]+float(rating)
                platform_df.loc[k,"rating count"]=platform_df.loc[k,"rating count"]+int(rating_count)

# %%
platform_df["avg rating"]=platform_df["rating"]/platform_df["rating count"]

platform_df
# Out:
#     ID               name  number of games    rating  rating count  avg rating
# 0    1                 PC           234078  95163.47         24975    3.810349
# 1    2        PlayStation            15288  80981.22         21113    3.835609
# 2    3               Xbox             6668  76381.75         20132    3.794047
# 3    4                iOS            66313   7683.64          2003    3.836066
# 4    8            Android            30130   1792.80           513    3.494737
# 5    5    Apple Macintosh            54825  21540.35          5565    3.870683
# 6    6              Linux            36499  10841.75          2737    3.961180
# 7    7           Nintendo            15439  41574.06         10814    3.844466
# 8    9              Atari             1635      0.00             0         NaN
# 9   10  Commodore / Amiga             2025      0.00             0         NaN
# 10  11               SEGA             1981      0.00             0         NaN
# 11  12                3DO               88      0.00             0         NaN
# 12  13            Neo Geo               97      0.00             0         NaN
# 13  14                Web            88574   1731.30           455    3.805055
