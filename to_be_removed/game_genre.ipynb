# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
# import data
game_df=pd.read_csv("csvfiles/game.csv",parse_dates=["release date"])
game_df
# Out:
#       Unnamed: 0                                      name      id  \
# 0              0                  The Witcher 3: Wild Hunt    3328
# 1              1                           Life is Strange    3439
# 2              2                     Red Dead Redemption 2      28
# 3              3                               DOOM (2016)    2454
# 4              4                                 Fallout 4    3070
# ...          ...                                       ...     ...
# 1182        1182                   AO International Tennis   58354
# 1183        1183                  Far Cry 5 - Lost On Mars  319111
# 1184        1184  CATS: Crash Arena Turbo Stars (C.A.T.S.)   21848
# 1185        1185                                Card Thief     334
# 1186        1186                    Fallout 4 - Far Harbor  289929
#
#       number of platforms                                          platforms  \
# 0                       4          ['PC', 'PlayStation', 'Xbox', 'Nintendo']
# 1                       9  ['PC', 'PlayStation', 'Xbox', 'iOS', 'Android'...
# 2                       3                      ['PC', 'PlayStation', 'Xbox']
# 3                       4          ['PC', 'PlayStation', 'Xbox', 'Nintendo']
# 4                       3                      ['PC', 'PlayStation', 'Xbox']
# ...                   ...                                                ...
# 1182                    3                      ['PC', 'PlayStation', 'Xbox']
# 1183                    3                      ['PC', 'PlayStation', 'Xbox']
# 1184                    2                                 ['iOS', 'Android']
# 1185                    2                                 ['iOS', 'Android']
# 1186                    3                      ['PC', 'PlayStation', 'Xbox']
#
#       number of stores                                             stores  \
# 0                    4  ['Steam', 'PlayStation Store', 'Xbox Store', '...
# 1                    7  ['Steam', 'PlayStation Store', 'Xbox Store', '...
# 2                    4  ['Steam', 'PlayStation Store', 'Xbox Store', '...
# 3                    4  ['Steam', 'PlayStation Store', 'Xbox Store', '...
# 4                    3       ['Steam', 'PlayStation Store', 'Xbox Store']
# ...                ...                                                ...
# 1182                 3       ['Steam', 'PlayStation Store', 'Xbox Store']
# 1183                 3       ['Steam', 'PlayStation Store', 'Xbox Store']
# 1184                 2                       ['App Store', 'Google Play']
# 1185                 2                       ['App Store', 'Google Play']
# 1186                 3       ['Steam', 'PlayStation Store', 'Xbox Store']
#
#       number of genres                          genres  \
# 0                    3  ['Adventure', 'Action', 'RPG']
# 1                    1                   ['Adventure']
# 2                    2         ['Adventure', 'Action']
# 3                    2           ['Shooter', 'Action']
# 4                    2               ['Action', 'RPG']
# ...                ...                             ...
# 1182                 1                      ['Sports']
# 1183                 2         ['Adventure', 'Action']
# 1184                 3  ['Casual', 'Arcade', 'Action']
# 1185                 2         ['Card', 'Board Games']
# 1186                 3    ['Shooter', 'Action', 'RPG']
#
#                                                    tags release date  rating  \
# 0     ['Full controller support', 'Action RPG', 'Atm...   2015-05-18    4.67
# 1     ['Full controller support', 'Atmospheric', 'Ch...   2015-01-29    4.10
# 2     ['In-App Purchases', 'America', 'Partial Contr...   2018-10-26    4.56
# 3     ['Partial Controller Support', 'Steam Achievem...   2016-05-13    4.40
# 4     ['Full controller support', 'Action RPG', 'Ste...   2015-11-09    3.75
# ...                                                 ...          ...     ...
# 1182  ['Full controller support', 'Steam Achievement...   2018-05-07    3.45
# 1183  ['Mars', 'Space', 'Story', 'gun', 'Gravity', '...   2018-07-17    3.57
# 1184               ['Asynchronous Multiplayer', 'Cute']   2017-04-19    3.79
# 1185  ['Stealth', 'mobile', 'dungeon', 'solitaire', ...   2017-03-19    3.90
# 1186  ['Space', 'children', 'island', 'windows', 'st...   2016-05-19    3.92
#
#       max rating  rating count  metacritic score  \
# 0              5          3480                93
# 1              5          2222                83
# 2              5          2546                96
# 3              5          2178                85
# 4              4          1989                84
# ...          ...           ...               ...
# 1182           4            11                58
# 1183           5             7                59
# 1184           4            14                78
# 1185           4             9                88
# 1186           4            12                77
#
#                                                   added  month
# 0     {'yet': 559, 'owned': 6148, 'beaten': 2407, 't...      5
# 1     {'yet': 464, 'owned': 6157, 'beaten': 1914, 't...      1
# 2     {'yet': 402, 'owned': 4228, 'beaten': 1262, 't...     10
# 3     {'yet': 319, 'owned': 4864, 'beaten': 1524, 't...      5
# 4     {'yet': 294, 'owned': 4841, 'beaten': 1234, 't...     11
# ...                                                 ...    ...
# 1182  {'owned': 16, 'beaten': 2, 'toplay': 2, 'dropp...      5
# 1183  {'yet': 2, 'owned': 5, 'beaten': 7, 'toplay': ...      7
# 1184  {'yet': 1, 'owned': 5, 'beaten': 3, 'dropped':...      4
# 1185  {'yet': 2, 'owned': 4, 'beaten': 2, 'toplay': ...      3
# 1186  {'yet': 1, 'owned': 2, 'beaten': 16, 'toplay':...      5
#
# [1187 rows x 17 columns]

# %%
# get a dataframe of each game' genre and rating - note for games with multiple genre, rows are repeated
genre=[]
rating=[]
metacritic=[]

for i in game_df.index:
    curr_genre=game_df.loc[i,"genres"].split("'")
    genre.append(curr_genre[1])
    rating.append(game_df.loc[i,"rating"])
    metacritic.append(game_df.loc[i,"metacritic score"])

genre_df=pd.DataFrame(
    {
        "genre":genre,
        "rating":rating,
        "metacritic":metacritic
    }
)

genre_df
# Out:
#           genre  rating  metacritic
# 0     Adventure    4.67          93
# 1     Adventure    4.10          83
# 2     Adventure    4.56          96
# 3       Shooter    4.40          85
# 4        Action    3.75          84
# ...         ...     ...         ...
# 1182     Sports    3.45          58
# 1183  Adventure    3.57          59
# 1184     Casual    3.79          78
# 1185       Card    3.90          88
# 1186    Shooter    3.92          77
#
# [1187 rows x 3 columns]

# %%
game_df["first genre"]=genre
game_df
# Out:
#       Unnamed: 0                                      name      id  \
# 0              0                  The Witcher 3: Wild Hunt    3328
# 1              1                           Life is Strange    3439
# 2              2                     Red Dead Redemption 2      28
# 3              3                               DOOM (2016)    2454
# 4              4                                 Fallout 4    3070
# ...          ...                                       ...     ...
# 1182        1182                   AO International Tennis   58354
# 1183        1183                  Far Cry 5 - Lost On Mars  319111
# 1184        1184  CATS: Crash Arena Turbo Stars (C.A.T.S.)   21848
# 1185        1185                                Card Thief     334
# 1186        1186                    Fallout 4 - Far Harbor  289929
#
#       number of platforms                                          platforms  \
# 0                       4          ['PC', 'PlayStation', 'Xbox', 'Nintendo']
# 1                       9  ['PC', 'PlayStation', 'Xbox', 'iOS', 'Android'...
# 2                       3                      ['PC', 'PlayStation', 'Xbox']
# 3                       4          ['PC', 'PlayStation', 'Xbox', 'Nintendo']
# 4                       3                      ['PC', 'PlayStation', 'Xbox']
# ...                   ...                                                ...
# 1182                    3                      ['PC', 'PlayStation', 'Xbox']
# 1183                    3                      ['PC', 'PlayStation', 'Xbox']
# 1184                    2                                 ['iOS', 'Android']
# 1185                    2                                 ['iOS', 'Android']
# 1186                    3                      ['PC', 'PlayStation', 'Xbox']
#
#       number of stores                                             stores  \
# 0                    4  ['Steam', 'PlayStation Store', 'Xbox Store', '...
# 1                    7  ['Steam', 'PlayStation Store', 'Xbox Store', '...
# 2                    4  ['Steam', 'PlayStation Store', 'Xbox Store', '...
# 3                    4  ['Steam', 'PlayStation Store', 'Xbox Store', '...
# 4                    3       ['Steam', 'PlayStation Store', 'Xbox Store']
# ...                ...                                                ...
# 1182                 3       ['Steam', 'PlayStation Store', 'Xbox Store']
# 1183                 3       ['Steam', 'PlayStation Store', 'Xbox Store']
# 1184                 2                       ['App Store', 'Google Play']
# 1185                 2                       ['App Store', 'Google Play']
# 1186                 3       ['Steam', 'PlayStation Store', 'Xbox Store']
#
#       number of genres                          genres  \
# 0                    3  ['Adventure', 'Action', 'RPG']
# 1                    1                   ['Adventure']
# 2                    2         ['Adventure', 'Action']
# 3                    2           ['Shooter', 'Action']
# 4                    2               ['Action', 'RPG']
# ...                ...                             ...
# 1182                 1                      ['Sports']
# 1183                 2         ['Adventure', 'Action']
# 1184                 3  ['Casual', 'Arcade', 'Action']
# 1185                 2         ['Card', 'Board Games']
# 1186                 3    ['Shooter', 'Action', 'RPG']
#
#                                                    tags release date  rating  \
# 0     ['Full controller support', 'Action RPG', 'Atm...   2015-05-18    4.67
# 1     ['Full controller support', 'Atmospheric', 'Ch...   2015-01-29    4.10
# 2     ['In-App Purchases', 'America', 'Partial Contr...   2018-10-26    4.56
# 3     ['Partial Controller Support', 'Steam Achievem...   2016-05-13    4.40
# 4     ['Full controller support', 'Action RPG', 'Ste...   2015-11-09    3.75
# ...                                                 ...          ...     ...
# 1182  ['Full controller support', 'Steam Achievement...   2018-05-07    3.45
# 1183  ['Mars', 'Space', 'Story', 'gun', 'Gravity', '...   2018-07-17    3.57
# 1184               ['Asynchronous Multiplayer', 'Cute']   2017-04-19    3.79
# 1185  ['Stealth', 'mobile', 'dungeon', 'solitaire', ...   2017-03-19    3.90
# 1186  ['Space', 'children', 'island', 'windows', 'st...   2016-05-19    3.92
#
#       max rating  rating count  metacritic score  \
# 0              5          3480                93
# 1              5          2222                83
# 2              5          2546                96
# 3              5          2178                85
# 4              4          1989                84
# ...          ...           ...               ...
# 1182           4            11                58
# 1183           5             7                59
# 1184           4            14                78
# 1185           4             9                88
# 1186           4            12                77
#
#                                                   added  month    temp  \
# 0     {'yet': 559, 'owned': 6148, 'beaten': 2407, 't...      5  735736
# 1     {'yet': 464, 'owned': 6157, 'beaten': 1914, 't...      1  735627
# 2     {'yet': 402, 'owned': 4228, 'beaten': 1262, 't...     10  736993
# 3     {'yet': 319, 'owned': 4864, 'beaten': 1524, 't...      5  736097
# 4     {'yet': 294, 'owned': 4841, 'beaten': 1234, 't...     11  735911
# ...                                                 ...    ...     ...
# 1182  {'owned': 16, 'beaten': 2, 'toplay': 2, 'dropp...      5  736821
# 1183  {'yet': 2, 'owned': 5, 'beaten': 7, 'toplay': ...      7  736892
# 1184  {'yet': 1, 'owned': 5, 'beaten': 3, 'dropped':...      4  736438
# 1185  {'yet': 2, 'owned': 4, 'beaten': 2, 'toplay': ...      3  736407
# 1186  {'yet': 1, 'owned': 2, 'beaten': 16, 'toplay':...      5  736103
#
#      first genre
# 0      Adventure
# 1      Adventure
# 2      Adventure
# 3        Shooter
# 4         Action
# ...          ...
# 1182      Sports
# 1183   Adventure
# 1184      Casual
# 1185        Card
# 1186     Shooter
#
# [1187 rows x 19 columns]

# %%
# get summary of rating by genre

genre_summary=pd.DataFrame(genre_df.groupby("genre").agg(["count","mean","median","var","std","sem"]))

genre_summary
# Out:
#                       rating                                                 \
#                        count      mean median       var       std       sem
# genre
# Action                   110  3.592000  3.695  0.380036  0.616471  0.058778
# Adventure                199  3.676884  3.720  0.300512  0.548190  0.038860
# Arcade                    12  3.675000  3.720  0.109845  0.331429  0.095675
# Card                       6  3.701667  3.695  0.223537  0.472797  0.193018
# Casual                    72  3.566389  3.750  0.325530  0.570553  0.067240
# Educational                4  3.267500  3.330  0.396825  0.629940  0.314970
# Family                     8  3.786250  3.710  0.099455  0.315365  0.111499
# Fighting                   5  3.740000  3.630  0.241000  0.490918  0.219545
# Indie                    362  3.425138  3.470  0.330817  0.575167  0.030230
# Massively Multiplayer     12  3.272500  3.220  0.221075  0.470186  0.135731
# Platformer                28  3.867500  4.055  0.387101  0.622174  0.117580
# Puzzle                     1  4.300000  4.300       NaN       NaN       NaN
# RPG                       34  3.850882  3.935  0.270548  0.520142  0.089204
# Racing                    48  3.492917  3.475  0.189349  0.435142  0.062807
# Shooter                   95  3.542947  3.590  0.310974  0.557651  0.057214
# Simulation                12  3.663333  3.640  0.123115  0.350878  0.101290
# Sports                    13  3.420000  3.420  0.070367  0.265267  0.073572
# Strategy                 159  3.482956  3.540  0.337267  0.580747  0.046056
#
#                       metacritic                                           \
#                            count       mean median         var        std
# genre
# Action                       110  75.681818   76.0   99.576731   9.978814
# Adventure                    199  74.753769   76.0  106.418862  10.315952
# Arcade                        12  75.666667   75.5   80.787879   8.988208
# Card                           6  80.333333   80.0   40.266667   6.345602
# Casual                        72  75.111111   76.0   63.226917   7.951536
# Educational                    4  77.750000   80.0   46.916667   6.849574
# Family                         8  76.375000   77.5   73.410714   8.568005
# Fighting                       5  77.400000   77.0  130.300000  11.414903
# Indie                        362  73.403315   75.0   84.374283   9.185547
# Massively Multiplayer         12  75.583333   77.0   62.446970   7.902340
# Platformer                    28  82.535714   82.5   42.332011   6.506305
# Puzzle                         1  80.000000   80.0         NaN        NaN
# RPG                           34  75.941176   80.0  115.511586  10.747632
# Racing                        48  75.062500   75.5  100.825798  10.041205
# Shooter                       95  74.136842   78.0  132.587458  11.514663
# Simulation                    12  73.416667   73.0   99.356061   9.967751
# Sports                        13  78.384615   79.0   62.256410   7.890273
# Strategy                     159  76.132075   76.0   64.241939   8.015107
#
#
#                             sem
# genre
# Action                 0.951443
# Adventure              0.731278
# Arcade                 2.594672
# Card                   2.590581
# Casual                 0.937097
# Educational            3.424787
# Family                 3.029247
# Fighting               5.104900
# Indie                  0.482782
# Massively Multiplayer  2.281209
# Platformer             1.229576
# Puzzle                      NaN
# RPG                    1.843204
# Racing                 1.449323
# Shooter                1.181379
# Simulation             2.877442
# Sports                 2.188368
# Strategy               0.635639

# %%
# only examining genre that have at list 100 ratings
top_genre=genre_summary.index[genre_summary["rating"]["count"]>100]
for i in genre_df.index:
    if genre_df.loc[i,"genre"] in top_genre:
        genre_df.loc[i,"top genre"]=True
    else:
        genre_df.loc[i,"top genre"]=False
genre_df
# Out:
#           genre  rating  metacritic top genre
# 0     Adventure    4.67          93      True
# 1     Adventure    4.10          83      True
# 2     Adventure    4.56          96      True
# 3       Shooter    4.39          85     False
# 4        Action    3.75          84      True
# ...         ...     ...         ...       ...
# 1175     Action    3.88          78      True
# 1176  Adventure    3.78          89      True
# 1177     Casual    3.79          78     False
# 1178  Adventure    3.57          59      True
# 1179       Card    3.90          88     False
#
# [1180 rows x 4 columns]

# %%
# get a shortened genre_df with only the top genres
genre_df_short=genre_df[genre_df["top genre"]==True]
genre_df_short
# Out:
#           genre  rating  metacritic top genre
# 0     Adventure    4.67          93      True
# 1     Adventure    4.10          83      True
# 2     Adventure    4.56          96      True
# 4        Action    3.75          84      True
# 5     Adventure    4.61          94      True
# ...         ...     ...         ...       ...
# 1171      Indie    2.25          40      True
# 1172  Adventure    1.83          27      True
# 1175     Action    3.88          78      True
# 1176  Adventure    3.78          89      True
# 1178  Adventure    3.57          59      True
#
# [830 rows x 4 columns]

# %%
genre_df_short.boxplot("rating",by="genre",figsize=(10,3),grid=False,\
                       notch=True,color="black",\
                       flierprops=dict(marker='x',markersize=7, markeredgecolor="red"))
plt.title("Box Plot of Average Game Rating by Genre",fontweight="bold")
plt.xlabel("Game Genre", fontweight="bold")
plt.ylabel("Average Game Rating", fontweight="bold")
plt.suptitle(" ")
# Out:
# Text(0.5, 0.98, ' ')

# %%
# testing whether results will be similar without outliers
genre_df_short_nooutlier=genre_df_short.copy()

for i in genre_df_short["genre"].unique():
    Q1=genre_df_short["rating"][genre_df_short["genre"]==i].quantile(.25)
    Q3=genre_df_short["rating"][genre_df_short["genre"]==i].quantile(.75)
    IQR=Q3-Q1
    lower_bound=Q1-(1.5*IQR)
    for j in genre_df_short_nooutlier.index:
        if (genre_df_short_nooutlier.loc[j,"genre"]==i) & (genre_df_short_nooutlier.loc[j,"rating"]<lower_bound):
            genre_df_short_nooutlier.loc[j,"outlier"]=True

genre_df_short_nooutlier=genre_df_short_nooutlier[genre_df_short_nooutlier["outlier"]!=True]
genre_df_short_nooutlier
# Out:
#           genre  rating  metacritic top genre outlier
# 0     Adventure    4.67          93      True     NaN
# 1     Adventure    4.10          83      True     NaN
# 2     Adventure    4.56          96      True     NaN
# 4        Action    3.75          84      True     NaN
# 5     Adventure    4.61          94      True     NaN
# ...         ...     ...         ...       ...     ...
# 1169     Action    4.05          76      True     NaN
# 1171      Indie    2.25          40      True     NaN
# 1175     Action    3.88          78      True     NaN
# 1176  Adventure    3.78          89      True     NaN
# 1178  Adventure    3.57          59      True     NaN
#
# [823 rows x 5 columns]

# %%
genre_df_short_nooutlier.boxplot("rating",by="genre",figsize=(10,3),grid=False,\
                       notch=True,color="black",\
                       flierprops=dict(marker='x',markersize=7, markeredgecolor="red"))
plt.title("Box Plot of Average Game Rating by Genre",fontweight="bold")
plt.xlabel("Game Genre", fontweight="bold")
plt.ylabel("Average Game Rating", fontweight="bold")
plt.suptitle(" ")
# Out:
# Text(0.5, 0.98, ' ')

# %%
genre_df_short.boxplot("metacritic",by="genre",figsize=(10,3),grid=False,\
                       notch=True,color="black",\
                       flierprops=dict(marker='x',markersize=7, markeredgecolor="red"))
plt.title("Box Plot of Average Game Rating by Genre",fontweight="bold")
plt.xlabel("Game Genre", fontweight="bold")
plt.ylabel("Average Game Rating", fontweight="bold")
plt.suptitle(" ")
# Out:
# Text(0.5, 0.98, ' ')

# %%
rating=[]
curr_rating=[]
metacritic=[]
curr_metacritic=[]
genre=[]

for i in genre_df_short["genre"].unique():
    curr_rating=genre_df_short["rating"][genre_df_short["genre"]==i]
    curr_metacritic=genre_df_short["metacritic"][genre_df_short["genre"]==i]
    rating.append(curr_rating)
    metacritic.append(curr_metacritic)
    genre.append(i)

# %%
rating_nooutlier=[]
curr_rating=[]
genre_nooutlier=[]

for i in genre_df_short_nooutlier["genre"].unique():
    curr_rating=genre_df_short_nooutlier["rating"][genre_df_short["genre"]==i]
    rating_nooutlier.append(curr_rating)
    genre_nooutlier.append(i)

# %%
stats.f_oneway(rating[0],rating[1],rating[2],rating[3])
# Out:
# F_onewayResult(statistic=8.997877333676033, pvalue=7.217283259724945e-06)

# %%
stats.f_oneway(rating_nooutlier[0],rating_nooutlier[1],rating_nooutlier[2],rating_nooutlier[3])
# Out:
# F_onewayResult(statistic=10.054833732658524, pvalue=1.6426504508742892e-06)

# %%
stats.f_oneway(metacritic[0],metacritic[1],metacritic[2],metacritic[3])
# Out:
# F_onewayResult(statistic=3.8837189640694483, pvalue=0.008983081197438791)

# %%
numtests=0
for i in range(len(genre)-1):
    numtests=numtests+(i+1)
numtests
# Out:
# 6

# %%
for i in range(len(genre)):
    for j in range(len(genre)):
        if genre[i]!=genre[j]:
            result=stats.ttest_ind(rating[i],rating[j],equal_var=False)
            if result.pvalue<(0.05/6):
                print(genre[i]+" "+genre[j]+" "+str(result))
# Out:
# Adventure Indie Ttest_indResult(statistic=5.113277480844542, pvalue=4.799136788195975e-07)
# Adventure Strategy Ttest_indResult(statistic=3.218187121830784, pvalue=0.001418199120430887)
# Indie Adventure Ttest_indResult(statistic=-5.113277480844542, pvalue=4.799136788195975e-07)
# Strategy Adventure Ttest_indResult(statistic=-3.218187121830784, pvalue=0.001418199120430887)

# %%
for i in range(len(genre_nooutlier)):
    for j in range(len(genre_nooutlier)):
        if genre_nooutlier[i]!=genre_nooutlier[j]:
            result=stats.ttest_ind(rating_nooutlier[i],rating_nooutlier[j],equal_var=False)
            if result.pvalue<(0.05/6):
                print(genre_nooutlier[i]+" "+genre_nooutlier[j]+" "+str(result))
# Out:
# Adventure Indie Ttest_indResult(statistic=5.382433867174905, pvalue=1.2175671245986434e-07)
# Adventure Strategy Ttest_indResult(statistic=3.431832969395447, pvalue=0.0006772124343264989)
# Action Indie Ttest_indResult(statistic=2.76960538322693, pvalue=0.00622581181974931)
# Indie Adventure Ttest_indResult(statistic=-5.382433867174905, pvalue=1.2175671245986434e-07)
# Indie Action Ttest_indResult(statistic=-2.76960538322693, pvalue=0.00622581181974931)
# Strategy Adventure Ttest_indResult(statistic=-3.431832969395447, pvalue=0.0006772124343264989)

# %%
for i in range(len(genre)):
    for j in range(len(genre)):
        if genre[i]!=genre[j]:
            result=stats.ttest_ind(metacritic[i],metacritic[j],equal_var=False)
            if result.pvalue<(0.001):
                print(genre[i]+" "+genre[j]+" "+str(result))
# Out:
# Indie Strategy Ttest_indResult(statistic=-3.4186634502049715, pvalue=0.0007050764534089871)
# Strategy Indie Ttest_indResult(statistic=3.4186634502049715, pvalue=0.0007050764534089871)

# %%
import seaborn as sns

sns.set(style="whitegrid")
sns.despine()
fig1=sns.swarmplot("genre","rating", data=genre_df_short,size=3)
fig1=sns.boxplot("genre","rating", data=genre_df_short,color="white")
fig1.set_title("Average game rating by genre",fontweight="bold")
fig1.text(3.6,4,"Adventure > Indie\nAdventure > Strategy\np-value=.00898", horizontalalignment="left", size="medium", color='black')
# Out:
# Text(3.6, 4, 'Adventure > Indie\nAdventure > Strategy\np-value=.00898')

# %%
#note to self - add trend with date
plt.scatter(game_df["release date"],game_df["rating"])
stats.linregress(game_df["temp"],game_df["rating"])
# Out:
# LinregressResult(slope=0.00021635270046222745, intercept=-155.7746350611212, rvalue=0.1908139066927894, pvalue=3.399197209914689e-11, stderr=3.233249923353861e-05)

# %%
import datetime as dt
game_df["temp"] = pd.to_datetime(game_df["release date"])
game_df["temp"]=game_df["temp"].map(dt.datetime.toordinal)
game_df
# Out:
#       Unnamed: 0                                      name      id  \
# 0              0                  The Witcher 3: Wild Hunt    3328
# 1              1                           Life is Strange    3439
# 2              2                     Red Dead Redemption 2      28
# 3              3                               DOOM (2016)    2454
# 4              4                                 Fallout 4    3070
# ...          ...                                       ...     ...
# 1182        1182                   AO International Tennis   58354
# 1183        1183                  Far Cry 5 - Lost On Mars  319111
# 1184        1184  CATS: Crash Arena Turbo Stars (C.A.T.S.)   21848
# 1185        1185                                Card Thief     334
# 1186        1186                    Fallout 4 - Far Harbor  289929
#
#       number of platforms                                          platforms  \
# 0                       4          ['PC', 'PlayStation', 'Xbox', 'Nintendo']
# 1                       9  ['PC', 'PlayStation', 'Xbox', 'iOS', 'Android'...
# 2                       3                      ['PC', 'PlayStation', 'Xbox']
# 3                       4          ['PC', 'PlayStation', 'Xbox', 'Nintendo']
# 4                       3                      ['PC', 'PlayStation', 'Xbox']
# ...                   ...                                                ...
# 1182                    3                      ['PC', 'PlayStation', 'Xbox']
# 1183                    3                      ['PC', 'PlayStation', 'Xbox']
# 1184                    2                                 ['iOS', 'Android']
# 1185                    2                                 ['iOS', 'Android']
# 1186                    3                      ['PC', 'PlayStation', 'Xbox']
#
#       number of stores                                             stores  \
# 0                    4  ['Steam', 'PlayStation Store', 'Xbox Store', '...
# 1                    7  ['Steam', 'PlayStation Store', 'Xbox Store', '...
# 2                    4  ['Steam', 'PlayStation Store', 'Xbox Store', '...
# 3                    4  ['Steam', 'PlayStation Store', 'Xbox Store', '...
# 4                    3       ['Steam', 'PlayStation Store', 'Xbox Store']
# ...                ...                                                ...
# 1182                 3       ['Steam', 'PlayStation Store', 'Xbox Store']
# 1183                 3       ['Steam', 'PlayStation Store', 'Xbox Store']
# 1184                 2                       ['App Store', 'Google Play']
# 1185                 2                       ['App Store', 'Google Play']
# 1186                 3       ['Steam', 'PlayStation Store', 'Xbox Store']
#
#       number of genres                          genres  \
# 0                    3  ['Adventure', 'Action', 'RPG']
# 1                    1                   ['Adventure']
# 2                    2         ['Adventure', 'Action']
# 3                    2           ['Shooter', 'Action']
# 4                    2               ['Action', 'RPG']
# ...                ...                             ...
# 1182                 1                      ['Sports']
# 1183                 2         ['Adventure', 'Action']
# 1184                 3  ['Casual', 'Arcade', 'Action']
# 1185                 2         ['Card', 'Board Games']
# 1186                 3    ['Shooter', 'Action', 'RPG']
#
#                                                    tags release date  rating  \
# 0     ['Full controller support', 'Action RPG', 'Atm...   2015-05-18    4.67
# 1     ['Full controller support', 'Atmospheric', 'Ch...   2015-01-29    4.10
# 2     ['In-App Purchases', 'America', 'Partial Contr...   2018-10-26    4.56
# 3     ['Partial Controller Support', 'Steam Achievem...   2016-05-13    4.40
# 4     ['Full controller support', 'Action RPG', 'Ste...   2015-11-09    3.75
# ...                                                 ...          ...     ...
# 1182  ['Full controller support', 'Steam Achievement...   2018-05-07    3.45
# 1183  ['Mars', 'Space', 'Story', 'gun', 'Gravity', '...   2018-07-17    3.57
# 1184               ['Asynchronous Multiplayer', 'Cute']   2017-04-19    3.79
# 1185  ['Stealth', 'mobile', 'dungeon', 'solitaire', ...   2017-03-19    3.90
# 1186  ['Space', 'children', 'island', 'windows', 'st...   2016-05-19    3.92
#
#       max rating  rating count  metacritic score  \
# 0              5          3480                93
# 1              5          2222                83
# 2              5          2546                96
# 3              5          2178                85
# 4              4          1989                84
# ...          ...           ...               ...
# 1182           4            11                58
# 1183           5             7                59
# 1184           4            14                78
# 1185           4             9                88
# 1186           4            12                77
#
#                                                   added  month    temp
# 0     {'yet': 559, 'owned': 6148, 'beaten': 2407, 't...      5  735736
# 1     {'yet': 464, 'owned': 6157, 'beaten': 1914, 't...      1  735627
# 2     {'yet': 402, 'owned': 4228, 'beaten': 1262, 't...     10  736993
# 3     {'yet': 319, 'owned': 4864, 'beaten': 1524, 't...      5  736097
# 4     {'yet': 294, 'owned': 4841, 'beaten': 1234, 't...     11  735911
# ...                                                 ...    ...     ...
# 1182  {'owned': 16, 'beaten': 2, 'toplay': 2, 'dropp...      5  736821
# 1183  {'yet': 2, 'owned': 5, 'beaten': 7, 'toplay': ...      7  736892
# 1184  {'yet': 1, 'owned': 5, 'beaten': 3, 'dropped':...      4  736438
# 1185  {'yet': 2, 'owned': 4, 'beaten': 2, 'toplay': ...      3  736407
# 1186  {'yet': 1, 'owned': 2, 'beaten': 16, 'toplay':...      5  736103
#
# [1187 rows x 18 columns]

# %%
plt.scatter(game_df["temp"][game_df["first genre"]=="Adventure"],game_df["rating"][game_df["first genre"]=="Adventure"],alpha=0.5,color="blue")
plt.scatter(game_df["temp"][game_df["first genre"]=="Indie"],game_df["rating"][game_df["first genre"]=="Indie"],alpha=0.5,color="red")
plt.scatter(game_df["temp"][game_df["first genre"]=="Strategy"],game_df["rating"][game_df["first genre"]=="Strategy"],alpha=0.5,color="green")

# %%
stats.linregress(game_df["temp"][game_df["first genre"]=="Strategy"],game_df["rating"][game_df["first genre"]=="Strategy"])
# Out:
# LinregressResult(slope=0.00042276197721966257, intercept=-307.7753398028456, rvalue=0.3406525883095986, pvalue=1.1143020588301398e-05, stderr=9.312143920049667e-05)
